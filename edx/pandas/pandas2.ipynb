# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
fichero=os.path.join(os.getcwd(),'datasets\\avocado.csv')
df=pd.read_csv(fichero)
#pasamos la fecha a tipo fecha
df['Date']=pd.to_datetime(df['Date'])
df.head()
albany_df=df[df['region']=='Albany']
albany_df.set_index('Date', inplace=True)
#ordenamos por el indice en este caso la fecha
df2=albany_df.sort_index()
#albany_df.sort_index(inplace=True)

#rolling (k) crea una ventana de k elementos para calcular
#por ejemplo el promedio o la suma movil
df2['AveragePrice'].rolling(25).mean().plot()

# %%
#los 25 primeros no tiene  valor por la ventana de 25, se pueden quitar
# dropna borra los  filas que tenen valores nulos
#dropna(axis='columns') las columnas que tengan nulos
#dropna(subset=['AveragePrice','Date']) mira los nulos de esas columnas
df3=df2['AveragePrice'].rolling(25).mean().dropna()
df3.head(3)
# Out:
# Date
# 2015-03-29    1.4660
# 2015-03-29    1.4580
# 2015-04-05    1.4328
# Name: AveragePrice, dtype: float64
